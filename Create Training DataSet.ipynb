# %% [markdown]
# ## Обучение моделей для задач Валидации Good/Agood/Bad и Группировки по 17 группам

# %% [markdown]
# Загрузка необходимых библиотек и модулей

# %%
from tokenization import token

# %% [markdown]
# ## Входные данные
# Загрузите в поле url ссылку на файл в docs.google.com

# %%
url = 'https://docs.google.com/spreadsheets/d/1ZiIBd0qoKzN937YNloVVcHbTzIg22b5SWiYzP2uAXoU/edit#gid=1631486485'

# %% [markdown]
# ## Создание обучающего датасета для модели Валидации по Good/Agood/Bad

# %%
token.create_training_data_set(url, validate=True)
# Out:
# Validation: Обработано 1 из 10691 задач
# Validation: Обработано 2 из 10691 задач
# Validation: Обработано 3 из 10691 задач
# Validation: Обработано 4 из 10691 задач
# Validation: Обработано 5 из 10691 задач
# Validation: Обработано 6 из 10691 задач
# Validation: Обработано 7 из 10691 задач
# Validation: Обработано 8 из 10691 задач
# Validation: Обработано 9 из 10691 задач
# Validation: Обработано 10 из 10691 задач
# Validation: Обработано 11 из 10691 задач
# Validation: Обработано 12 из 10691 задач
# Validation: Обработано 13 из 10691 задач
# Validation: Обработано 14 из 10691 задач
# Validation: Обработано 15 из 10691 задач
# Validation: Обработано 16 из 10691 задач
# Validation: Обработано 17 из 10691 задач
# Validation: Обработано 18 из 10691 задач
# Validation: Обработано 19 из 10691 задач
# Validation: Обработано 20 из 10691 задач
# Validation: Обработано 21 из 10691 задач
# Validation: Обработано 22 из 10691 задач
# Validation: Обработано 23 из 10691 задач
# ...

# %% [markdown]
# После окончания обработки данные сохраняются в директории **Data/training_validation_dataset.json** в файл, который автоматически подхватывается алгоритмом обучения модели

# %% [markdown]
# ## Создание обучающего датасета для модели Группировки по 17 группам

# %%
token.create_training_data_set(url, validate=False)
# Out:
# Grouping: Обработано 1 из 4991 задач
# Grouping: Обработано 2 из 4991 задач
# Grouping: Обработано 3 из 4991 задач
# Grouping: Обработано 4 из 4991 задач
# Grouping: Обработано 5 из 4991 задач
# Grouping: Обработано 6 из 4991 задач
# Grouping: Обработано 7 из 4991 задач
# Grouping: Обработано 8 из 4991 задач
# Grouping: Обработано 9 из 4991 задач
# Grouping: Обработано 10 из 4991 задач
# Grouping: Обработано 11 из 4991 задач
# Grouping: Обработано 12 из 4991 задач
# Grouping: Обработано 13 из 4991 задач
# Grouping: Обработано 14 из 4991 задач
# Grouping: Обработано 15 из 4991 задач
# Grouping: Обработано 16 из 4991 задач
# Grouping: Обработано 17 из 4991 задач
# Grouping: Обработано 18 из 4991 задач
# Grouping: Обработано 19 из 4991 задач
# Grouping: Обработано 20 из 4991 задач
# Grouping: Обработано 21 из 4991 задач
# Grouping: Обработано 22 из 4991 задач
# Grouping: Обработано 23 из 4991 задач
# Grouping: Обработано 24 из 4991 задач
# Grouping: Обработано 25 из 4991 задач
# ...

# %% [markdown]
# После окончания обработки данные сохраняются в директории **Data/training_grouping_dataset.json** в файл, который автоматически подхватывается алгоритмом обучения модели
